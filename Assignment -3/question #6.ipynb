# %%
#Write a Python program which takes two inputs from user and prinnt them addition.
x=int(input("Enter vale="));
y=int(input("Enter value="));
z=x+y;
print("Addition of two num=",z)
# Out:
# Enter vale=45
# Enter value=980
# Addition of two num= 1025
