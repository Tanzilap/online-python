# %%
#Write a program which take input from user and identify that the give nimber is even or odd?
n=int(input("Enter value="));
x=n%2
if x>0:
    print("Number is odd")
else:
    print("Number is even")
# Out:
# Enter value=5
# Number is odd
