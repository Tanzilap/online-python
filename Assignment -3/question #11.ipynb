# %%
#Write a Python program to get the larget number from a numeric list.
List1=[1, 3, 5, 6, 7, 34, 45, 56, 66, 76];
print("Largest number of the list :",max(List1))
# Out:
# Largest number of the list : 76
