# %%
# Write a Python script to check if a given key already exists in a dictionary.
a={1: 'orange',2: 'bananan'}
n=int(input("enter the key:"))
if n in a:
    print("Key is present ")
else:
    print("Key is not present")
# Out:
# enter the key:2
# Key is present
