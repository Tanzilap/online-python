# %%
# Write a program to identify duplicate values from liat.
x=[1,2,3,10,23,67,1,2,3]
y=[]
for i in x:
    if i not in y:
        y.append(i)
    else:
        print(i,end=' ')
        print(y)
# Out:
# 1 [1, 2, 3, 10, 23, 67]
# 2 [1, 2, 3, 10, 23, 67]
# 3 [1, 2, 3, 10, 23, 67]
